# %%
import numpy as np
import matplotlib.pylab as plt
import copy

import sys
sys.path.append('../')

from angler import Simulation, Optimization
from angler.structures import three_port, two_port
from angler.plot import *

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
lambda0 = 1.55e-6              # free space wavelength (m)
c0 = 3e8                    # speed of light in vacuum (m/s)
omega = 2*np.pi*c0/lambda0  # angular frequency (2pi/s)
dl = 0.005                # grid size (L0)
NPML = [25, 25]             # number of pml grid points on x and y borders
pol = 'Hz'                  # polarization (either 'Hz' or 'Ez')
source_amp = 2              # amplitude of modal source (A/L0^2?)

# %%
# material constants
# n_index = 2.44              # refractive index
n_index = 3.45             # refractive index
eps_m = n_index**2          # relative permittivity
chi3 = 4.1*1e-19            # Al2S3 from Boyd (m^2/V^2)
# max_ind_shift = 5.8e-3      # maximum allowed nonlinear refractive index shift (computed from damage threshold)

# %%
# geometric parameters
L = 10         # length of box (L0)
H = 2        # height of box (L0)
w = 0.48        # width of waveguides (L0)
d = H/2.44    # distance between waveguides (L0)
l = 4         # length of waveguide from PML to box (L0)
spc = 1.5       # space between box and PML (L0)

# %%
# define permittivity of three port system
eps_r, design_region = two_port(L, H, w, l, spc, dl, NPML, eps_m)
(Nx, Ny) = eps_r.shape
nx, ny = int(Nx/2), int(Ny/2)            # halfway grid points

simulation = Simulation(omega,eps_r,dl,NPML,pol)
# compute the grid size the total grid size
print("Computed a domain with {} grids in x and {} grids in y".format(Nx,Ny))
print("The simulation has {} grids per free space wavelength".format(int(lambda0/dl/simulation.L0)))
simulation.plt_eps()
plt.show()
# Out:
# Computed a domain with 1850 grids in x and 550 grids in y
# The simulation has 155 grids per free space wavelength

# %%
# set the modal source and probes
simulation = Simulation(omega, eps_r, dl, NPML, pol)
simulation.add_mode(np.sqrt(eps_m), 'x', [NPML[0]+int(l/2/dl), ny], int(Ny/3), scale=source_amp)
simulation.setup_modes()

# top modal profile
out = Simulation(omega, eps_r, dl, NPML, pol)
out.add_mode(np.sqrt(eps_m), 'x', [-NPML[0]-int(l/2/dl), ny], int(Ny/3))
out.setup_modes()
J_out = np.abs(out.src)

# %%
# set source and solve for electromagnetic fields
(_, _, Ez) = simulation.solve_fields()
simulation.plt_abs(outline=True, cbar=True)
# Out:
# <Axes: >

# %%
# compute straight line simulation
eps_r_wg, _ = two_port(L, H, w, l, spc, dl, NPML, eps_start=eps_m)
(Nx_wg, Ny_wg) = eps_r_wg.shape
nx_wg, ny_wg = int(Nx_wg/2), int(Ny_wg/2)            # halfway grid points     
simulation_wg = Simulation(omega, eps_r_wg, dl, NPML, 'Ez')
simulation_wg.add_mode(np.sqrt(eps_m), 'x', [NPML[0]+int(l/2/dl), ny_wg], int(Ny/3), scale=source_amp)
simulation_wg.setup_modes()

# compute normalization
sim_out = Simulation(omega, eps_r_wg, dl, NPML, 'Ez')
sim_out.add_mode(np.sqrt(eps_m), 'x', [-NPML[0]-int(l/2/dl), ny], int(Ny/3))
sim_out.setup_modes()
J_out = np.abs(sim_out.src)
(_, _, Ez_wg) = simulation_wg.solve_fields()
SCALE = np.sum(np.square(np.abs(Ez_wg))*J_out)
J_out = J_out/SCALE
print('computed a scale of {} in units of E^2 J_out'.format(SCALE))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 12
#      10 sim_out = Simulation(omega, eps_r_wg, dl, NPML, 'Ez')
#      11 sim_out.add_mode(np.sqrt(eps_m), 'x', [-NPML[0]-int(l/2/dl), ny], int(Ny/3))
# ---> 12 sim_out.setup_modes()
#      13 J_out = np.abs(sim_out.src)
#      14 (_, _, Ez_wg) = simulation_wg.solve_fields()
#
# File ~/pkgs/miniforge3/envs/python311venv/lib/python3.11/site-packages/angler/simulation.py:60, in Simulation.setup_modes(self)
#      57 def setup_modes(self):
#      58     # calculates
#      59     for modei in self.modes:
# ---> 60         modei.setup_src(self)
#
# File ~/pkgs/miniforge3/envs/python311venv/lib/python3.11/site-packages/angler/source/mode.py:21, in mode.setup_src(self, simulation, matrix_format)
#      19 def setup_src(self, simulation, matrix_format=DEFAULT_MATRIX_FORMAT):
#      20     # compute the input power here using an only waveguide simulation
# ---> 21     self.compute_normalization(simulation, matrix_format=matrix_format)
#      23     # insert the mode into the waveguide
#      24     self.insert_mode(simulation, simulation.src, matrix_format=matrix_format)
#
# File ~/pkgs/miniforge3/envs/python311venv/lib/python3.11/site-packages/angler/source/mode.py:54, in mode.compute_normalization(self, simulation, matrix_format)
#      52 simulation_norm.eps_r = norm_eps
#      53 self.insert_mode(simulation_norm, simulation_norm.src, matrix_format=matrix_format)
# ---> 54 simulation_norm.solve_fields()
#      55 W_in = simulation_norm.flux_probe(self.direction_normal, new_center, self.width)
#      57 # save this value in the original simulation
#
# File ~/pkgs/miniforge3/envs/python311venv/lib/python3.11/site-packages/angler/simulation.py:122, in Simulation.solve_fields(self, include_nl, timing, averaging, matrix_format)
#     120 if include_nl==False:
#     121     eps_tot = self.eps_r
# --> 122     X = solver_direct(self.A, self.src*1j*self.omega, timing=timing)
#     123 else:
#     124     eps_tot = self.eps_r + self.eps_nl
#
# File ~/pkgs/miniforge3/envs/python311venv/lib/python3.11/site-packages/angler/linalg.py:137, in solver_direct(A, b, timing, solver)
#     135 if solver.lower() == 'pardiso':
#     136     pSolve = pardisoSolver(A, mtype=13) # Matrix is complex unsymmetric due to SC-PML
# --> 137     pSolve.factor()
#     138     x = pSolve.solve(b)
#     139     pSolve.clear()
#
# File ~/pkgs/miniforge3/envs/python311venv/lib/python3.11/site-packages/pyMKL/pardisoSolver.py:146, in pardisoSolver.factor(self)
#     145 def factor(self):
# --> 146     out = self.run_pardiso(phase=12)
#
# File ~/pkgs/miniforge3/envs/python311venv/lib/python3.11/site-packages/pyMKL/pardisoSolver.py:205, in pardisoSolver.run_pardiso(self, phase, rhs)
#     202 MKL_x = x.ctypes.data_as(self.ctypes_dtype)
#     203 ERR = 0
# --> 205 pardiso(self._MKL_pt,               # pt
#     206         byref(c_int(self.maxfct)),  # maxfct
#     207         byref(c_int(self.mnum)),    # mnum
#     208         byref(c_int(self.mtype)),   # mtype
#     209         byref(c_int(phase)),        # phase
#     210         byref(c_int(self.n)),       # n
#     211         self._MKL_a,                # a
#     212         self._MKL_ia,               # ia
#     213         self._MKL_ja,               # ja
#     214         byref(c_int(self.perm)),    # perm
#     215         byref(c_int(nrhs)),         # nrhs
#     216         self._MKL_iparm,            # iparm
#     217         byref(c_int(self.msglvl)),  # msglvl
#     218         MKL_rhs,                    # b
#     219         MKL_x,                      # x
#     220         byref(c_int(ERR)))          # error
#     222 if nrhs > 1:
#     223     x = x.reshape((self.n, nrhs), order='f')
#
# KeyboardInterrupt:

# %%
# changes design region. 'style' can be in {'full', 'empty', 'halfway', 'random'}
print("this is the shape of design region: ", design_region.shape)
simulation.init_design_region(design_region, eps_m, style='halfway')
simulation.plt_eps()
plt.show()
# Out:
# this is the shape of design region:  (500, 175)

# %%
# add nonlinearity
nl_region = copy.deepcopy(design_region)

simulation.nonlinearity = []  # This is needed in case you re-run this cell, for example (or you can re-initialize simulation every time)
simulation.add_nl(chi3, nl_region, eps_scale=True, eps_max=eps_m)

# %%
# define objective function
from angler.objective import Objective, obj_arg
arg1 = obj_arg('ez', component='Ez', nl=False)
arg2 = obj_arg('ez_nl', component='Ez', nl=True)

import autograd.numpy as npa
def J(e, e_nl):
    linear_out =     1*npa.sum(npa.square(npa.abs(e))*J_out)
    nonlinear_out = -1*npa.sum(npa.square(npa.abs(e_nl))*J_out)
    return linear_out + nonlinear_out

objective = Objective(J, arg_list=[arg1, arg2])

# %%
# make optimization object and check derivatives
R = 2   # filter radius of curvature (pixels)  (takes a while to set up as R > 5 - 10)
beta = 100
eta= 0.5
optimization = Optimization(objective=objective, simulation=simulation, design_region=design_region, eps_m=eps_m, R=R, beta=beta, eta=eta)
# Out:
#  98% (440 of 445) |##################### | Elapsed Time: 0:00:06 ETA:   0:00:00

# %%
# check the derivatives (note, full derivatives are checked, linear and nonlinear no longer separate)
(grad_avm, grad_num) = optimization.check_deriv(Npts=5, d_rho=1e-4)
print('adjoint gradient   = {}\nnumerical gradient = {}'.format(grad_avm, grad_num))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 2
#       1 # check the derivatives (note, full derivatives are checked, linear and nonlinear no longer separate)
# ----> 2 (grad_avm, grad_num) = optimization.check_deriv(Npts=5, d_rho=1e-4)
#       3 print('adjoint gradient   = {}\nnumerical gradient = {}'.format(grad_avm, grad_num))
#
# File ~/pkgs/miniforge3/envs/python311venv/lib/python3.11/site-packages/angler/optimization.py:112, in Optimization.check_deriv(self, Npts, d_rho)
#     108 self.simulation.eps_r = rho2eps(rho=self.simulation.rho, eps_m=self.eps_m, W=self.W,
#     109                                 eta=self.eta, beta=self.beta)
#     111 # solve for the linear fields and grad of the linear objective function
# --> 112 grad_avm = self.compute_dJ(self.simulation, self.design_region)
#     113 J_orig = self.compute_J(self.simulation)
#     115 avm_grads = []
#
# File ~/pkgs/miniforge3/envs/python311venv/lib/python3.11/site-packages/angler/optimization.py:90, in Optimization.compute_dJ(self, simulation, design_region)
#      87 """ Returns the current grad of a simulation"""
#      89 # stores all of the fields for the objective function in self.field_arg_list
# ---> 90 self._solve_objfn_arg_fields(simulation)
#      92 # sum up gradient contributions from each argument in J
#      93 gradient_sum = 0
#
# File ~/pkgs/miniforge3/envs/python311venv/lib/python3.11/site-packages/angler/optimization.py:67, in Optimization._solve_objfn_arg_fields(self, simulation)
#      65         field = simulation.fields_nl[arg.component]
#      66     if field is None:
# ---> 67         raise ValueError("couldn't find a field defined for component '{}'.  Could be the wrong polarization (simulation is '{}' polarization).".format(arg.component, self.simulation.pol))
#      68     field_arg_list.append(field)
#      70 # store these arguments (so that they dont have to be recomputed)
#
# ValueError: couldn't find a field defined for component 'Ez'.  Could be the wrong polarization (simulation is 'Hz' polarization).

# %%
new_eps = optimization.run(method='lbfgs', Nsteps=2)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =        12250     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.63414D-06    |proj g|=  1.19557D-05
#  ObjectiveFn: ------ Iteration:  0/2 ETA:  --:--:--
# At iterate    1    f= -1.74091D-06    |proj g|=  1.19478D-05
#  ObjectiveFn: 8.52e-06 Iteration:  1/2 ETA:   0:00:02
# At iterate    2    f= -8.52336D-06    |proj g|=  3.94089D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
# 12250      2      3      2     0     0   3.941D-05  -8.523D-06
#   F =  -8.5233618759561480E-006
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(16,5))
simulation.plt_eps(ax=ax1, outline=False)
ax1.set_title('final permittivity distribution')
optimization.plt_objs(ax=ax2)
ax2.set_yscale('linear')
plt.show()

# %%
# compare the linear and nonlinear fields

# setup subplots
f, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(20,5))

# linear fields
(Hx,Hy,Ez) = simulation.solve_fields()
simulation.plt_abs(ax=ax1, vmax=None)
ax1.set_title('linear field')

# nonlinear fields
(Hx_nl,Hy_nl,Ez_nl,_) = simulation.solve_fields_nl()
simulation.plt_abs(ax=ax2, vmax=None, nl=True)
ax2.set_title('nonlinear field')

# difference
simulation.plt_diff(ax=ax3)
ax3.set_title('|Ez| for linear - nonlinear')

plt.show()

# %%
# compute the refractive index shift
index_shift = simulation.compute_index_shift()
print('maximum refractive index shift of {}'.format(np.max(index_shift)))
plt.imshow(index_shift.T, cmap='magma', origin='lower')
plt.colorbar()
plt.title('refractive index shift')
plt.show()
# Out:
# maximum refractive index shift of 9.40517492331594e-07

# %%
# compute powers

# input power
W_in = simulation.W_in

# linear powers
(Hx,Hy,Ez) = simulation.solve_fields()
W_out_lin = simulation.flux_probe('x', [-NPML[0]-int(l/2/dl), ny], int(Ny/2))
W_in_lin = simulation.flux_probe('x', [NPML[0]+int(2*l/3/dl), ny], int(Ny/2))

T_lin = W_out_lin/W_in

# nonlinear powers
(Hx_nl,Hy_nl,Ez_nl,_) = simulation.solve_fields_nl()
W_out_nl = simulation.flux_probe('x', [-NPML[0]-int(l/2/dl), ny], int(Ny/2), nl=True)
W_in_nl = simulation.flux_probe('x', [NPML[0]+int(2*l/3/dl), ny], int(Ny/2), nl=True)

T_nl = W_out_nl/W_in

print('linear transmission              = {:.4f}'.format(T_lin))
print('nonlinear transmission           = {:.4f}\n'.format(T_nl))
print('relative power difference        = {:.2f} %'.format(100*abs(W_out_lin-W_out_nl)/W_out_lin))
print('relative transmission difference = {:.2f} %'.format(100*abs(T_lin-T_nl)/T_lin))
# Out:
# linear transmission              = 0.5196
# nonlinear transmission           = 0.5196
#
# relative power difference        = 0.00 %
# relative transmission difference = 0.00 %
